# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

#from scipy.stats import linregress
import json
from pprint import pprint

all_agencies = "agencies/all_agencies.csv" #this csv provides all the agencies reporting crime in the subject 4 cities
agency_df = pd.read_csv(all_agencies)

fbi_url = "https://api.usa.gov/crime/fbi/sapi/"

from config import fbi_key

agencies = agency_df["ori"]
pol_officer=[]

# %%
for agency in agencies:

#`https://api.usa.gov/crime/fbi/sapi/{desired_endpiont}?api_key'
    url = f"https://api.usa.gov/crime/fbi/sapi/api/police-employment/agencies/{agency}/2018/2019?API_KEY={fbi_key}"
    response = requests.get(url)
    response_json = response.json()
    
    pol_officer.extend(response_json["results"])

    #if we want to do specific offenses, put offenses in as {offenses}
    #print(response_json['results'])
pol_officer_df=pd.DataFrame(pol_officer)
pol_officer_df
# Out:
#      data_year  civilian_ct  female_civilian_ct  female_officer_ct  \
# 0         2018          2.0                 2.0                2.0
# 1         2019          2.0                 2.0                3.0
# 2         2018          1.0                 1.0                0.0
# 3         2019          1.0                 1.0                0.0
# 4         2018          NaN                 NaN                NaN
# ..         ...          ...                 ...                ...
# 113       2019         12.0                 8.0                0.0
# 114       2018          NaN                 NaN                NaN
# 115       2019          9.0                 7.0                2.0
# 116       2018         98.0                76.0               34.0
# 117       2019         93.0                73.0               37.0
#
#      female_total_ct  male_civilian_ct  male_officer_ct  male_total_ct  \
# 0                4.0               0.0              9.0            9.0
# 1                5.0               0.0             12.0           12.0
# 2                1.0               0.0             12.0           12.0
# 3                1.0               0.0             13.0           13.0
# 4                NaN               NaN              NaN            NaN
# ..               ...               ...              ...            ...
# 113              8.0               4.0             30.0           34.0
# 114              NaN               NaN              NaN            NaN
# 115              9.0               2.0             18.0           20.0
# 116            110.0              22.0            215.0          237.0
# 117            110.0              20.0            204.0          224.0
#
#      population  total_pe_ct        ori  \
# 0             0         13.0  TX0153500
# 1             0         17.0  TX0153500
# 2          2434         13.0  TX0151100
# 3          2478         14.0  TX0151100
# 4        300332          NaN  TX0150000
# ..          ...          ...        ...
# 113        9033         42.0  TX1551400
# 114       10587          NaN  TX1550100
# 115       10817         29.0  TX1550100
# 116      138091        347.0  TX1551200
# 117      139870        334.0  TX1551200
#
#                                 ncic_agency_name  \
# 0    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO
# 1    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO
# 2                      OLMOS PARK PD SAN ANTONIO
# 3                      OLMOS PARK PD SAN ANTONIO
# 4                        BEXAR CO SO SAN ANTONIO
# ..                                           ...
# 113                              WOODWAY PD WACO
# 114                                  BELLMEAD PD
# 115                                  BELLMEAD PD
# 116                                      WACO PD
# 117                                      WACO PD
#
#                                 agency_name_edit agency_type_name state_abbr  \
# 0    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO            Other         TX
# 1    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO            Other         TX
# 2                      OLMOS PARK PD SAN ANTONIO             City         TX
# 3                      OLMOS PARK PD SAN ANTONIO             City         TX
# 4                        BEXAR CO SO SAN ANTONIO           County         TX
# ..                                           ...              ...        ...
# 113                              WOODWAY PD WACO             City         TX
# 114                                  BELLMEAD PD             City         TX
# 115                                  BELLMEAD PD             City         TX
# 116                                      WACO PD             City         TX
# 117                                      WACO PD             City         TX
#
#                                             csv_header  pe_ct_per_1000
# 0    data_year,ori,state_abbr,agency_name_edit,agen...             NaN
# 1    data_year,ori,state_abbr,agency_name_edit,agen...             NaN
# 2    data_year,ori,state_abbr,agency_name_edit,agen...            5.34
# 3    data_year,ori,state_abbr,agency_name_edit,agen...            5.65
# 4    data_year,ori,state_abbr,agency_name_edit,agen...             NaN
# ..                                                 ...             ...
# 113  data_year,ori,state_abbr,agency_name_edit,agen...            4.65
# 114  data_year,ori,state_abbr,agency_name_edit,agen...             NaN
# 115  data_year,ori,state_abbr,agency_name_edit,agen...            2.68
# 116  data_year,ori,state_abbr,agency_name_edit,agen...            2.51
# 117  data_year,ori,state_abbr,agency_name_edit,agen...            2.39
#
# [118 rows x 17 columns]

# %%
#https://api.usa.gov/crime/fbi/sapi/api/police-employment/agencies/TX0153500/2018/2019?API_KEY=iiHnOKfno2Mgkt5AynpvPpUQTEyxE77jo1RU8PIv

# %%
agency_df
merge_df = pd.merge(agency_df, pol_officer_df, on = "ori")
merge_df
# Out:
#      Unnamed: 0        ori    county  \
# 0             0  TX0153500     BEXAR
# 1             0  TX0153500     BEXAR
# 2             1  TX0151100     BEXAR
# 3             1  TX0151100     BEXAR
# 4             2  TX0150000     BEXAR
# ..          ...        ...       ...
# 113          56  TX1551400  MCLENNAN
# 114          57  TX1550100  MCLENNAN
# 115          57  TX1550100  MCLENNAN
# 116          58  TX1551200  MCLENNAN
# 117          58  TX1551200  MCLENNAN
#
#                                           name region        lat        lon  \
# 0    Independent School District: East Central  South  29.448671 -98.520147
# 1    Independent School District: East Central  South  29.448671 -98.520147
# 2                 Olmos Park Police Department  South  29.471867 -98.490600
# 3                 Olmos Park Police Department  South  29.471867 -98.490600
# 4                Bexar County Sheriff's Office  South  29.429178 -98.507170
# ..                                         ...    ...        ...        ...
# 113                  Woodway Police Department  South  31.506077 -97.227930
# 114                 Bellmead Police Department  South  31.589613 -97.100780
# 115                 Bellmead Police Department  South  31.589613 -97.100780
# 116                     Waco Police Department  South  31.549493 -97.201472
# 117                     Waco Police Department  South  31.549493 -97.201472
#
#                   lat,lon  data_year  civilian_ct  ...  male_officer_ct  \
# 0    29.448671,-98.520147       2018          2.0  ...              9.0
# 1    29.448671,-98.520147       2019          2.0  ...             12.0
# 2      29.471867,-98.4906       2018          1.0  ...             12.0
# 3      29.471867,-98.4906       2019          1.0  ...             13.0
# 4     29.429178,-98.50717       2018          NaN  ...              NaN
# ..                    ...        ...          ...  ...              ...
# 113   31.506077,-97.22793       2019         12.0  ...             30.0
# 114   31.589613,-97.10078       2018          NaN  ...              NaN
# 115   31.589613,-97.10078       2019          9.0  ...             18.0
# 116  31.549493,-97.201472       2018         98.0  ...            215.0
# 117  31.549493,-97.201472       2019         93.0  ...            204.0
#
#      male_total_ct  population  total_pe_ct  \
# 0              9.0           0         13.0
# 1             12.0           0         17.0
# 2             12.0        2434         13.0
# 3             13.0        2478         14.0
# 4              NaN      300332          NaN
# ..             ...         ...          ...
# 113           34.0        9033         42.0
# 114            NaN       10587          NaN
# 115           20.0       10817         29.0
# 116          237.0      138091        347.0
# 117          224.0      139870        334.0
#
#                                 ncic_agency_name  \
# 0    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO
# 1    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO
# 2                      OLMOS PARK PD SAN ANTONIO
# 3                      OLMOS PARK PD SAN ANTONIO
# 4                        BEXAR CO SO SAN ANTONIO
# ..                                           ...
# 113                              WOODWAY PD WACO
# 114                                  BELLMEAD PD
# 115                                  BELLMEAD PD
# 116                                      WACO PD
# 117                                      WACO PD
#
#                                 agency_name_edit  agency_type_name  \
# 0    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO             Other
# 1    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO             Other
# 2                      OLMOS PARK PD SAN ANTONIO              City
# 3                      OLMOS PARK PD SAN ANTONIO              City
# 4                        BEXAR CO SO SAN ANTONIO            County
# ..                                           ...               ...
# 113                              WOODWAY PD WACO              City
# 114                                  BELLMEAD PD              City
# 115                                  BELLMEAD PD              City
# 116                                      WACO PD              City
# 117                                      WACO PD              City
#
#      state_abbr                                         csv_header  \
# 0            TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 1            TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 2            TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 3            TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 4            TX  data_year,ori,state_abbr,agency_name_edit,agen...
# ..          ...                                                ...
# 113          TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 114          TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 115          TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 116          TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 117          TX  data_year,ori,state_abbr,agency_name_edit,agen...
#
#     pe_ct_per_1000
# 0              NaN
# 1              NaN
# 2             5.34
# 3             5.65
# 4              NaN
# ..             ...
# 113           4.65
# 114            NaN
# 115           2.68
# 116           2.51
# 117           2.39
#
# [118 rows x 24 columns]

# %%
merge_df=merge_df.fillna(0)
merge_df
# Out:
#      Unnamed: 0        ori    county  \
# 0             0  TX0153500     BEXAR
# 1             0  TX0153500     BEXAR
# 2             1  TX0151100     BEXAR
# 3             1  TX0151100     BEXAR
# 4             2  TX0150000     BEXAR
# ..          ...        ...       ...
# 113          56  TX1551400  MCLENNAN
# 114          57  TX1550100  MCLENNAN
# 115          57  TX1550100  MCLENNAN
# 116          58  TX1551200  MCLENNAN
# 117          58  TX1551200  MCLENNAN
#
#                                           name region        lat        lon  \
# 0    Independent School District: East Central  South  29.448671 -98.520147
# 1    Independent School District: East Central  South  29.448671 -98.520147
# 2                 Olmos Park Police Department  South  29.471867 -98.490600
# 3                 Olmos Park Police Department  South  29.471867 -98.490600
# 4                Bexar County Sheriff's Office  South  29.429178 -98.507170
# ..                                         ...    ...        ...        ...
# 113                  Woodway Police Department  South  31.506077 -97.227930
# 114                 Bellmead Police Department  South  31.589613 -97.100780
# 115                 Bellmead Police Department  South  31.589613 -97.100780
# 116                     Waco Police Department  South  31.549493 -97.201472
# 117                     Waco Police Department  South  31.549493 -97.201472
#
#                   lat,lon  data_year  civilian_ct  ...  male_officer_ct  \
# 0    29.448671,-98.520147       2018          2.0  ...              9.0
# 1    29.448671,-98.520147       2019          2.0  ...             12.0
# 2      29.471867,-98.4906       2018          1.0  ...             12.0
# 3      29.471867,-98.4906       2019          1.0  ...             13.0
# 4     29.429178,-98.50717       2018          0.0  ...              0.0
# ..                    ...        ...          ...  ...              ...
# 113   31.506077,-97.22793       2019         12.0  ...             30.0
# 114   31.589613,-97.10078       2018          0.0  ...              0.0
# 115   31.589613,-97.10078       2019          9.0  ...             18.0
# 116  31.549493,-97.201472       2018         98.0  ...            215.0
# 117  31.549493,-97.201472       2019         93.0  ...            204.0
#
#      male_total_ct  population  total_pe_ct  \
# 0              9.0           0         13.0
# 1             12.0           0         17.0
# 2             12.0        2434         13.0
# 3             13.0        2478         14.0
# 4              0.0      300332          0.0
# ..             ...         ...          ...
# 113           34.0        9033         42.0
# 114            0.0       10587          0.0
# 115           20.0       10817         29.0
# 116          237.0      138091        347.0
# 117          224.0      139870        334.0
#
#                                 ncic_agency_name  \
# 0    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO
# 1    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO
# 2                      OLMOS PARK PD SAN ANTONIO
# 3                      OLMOS PARK PD SAN ANTONIO
# 4                        BEXAR CO SO SAN ANTONIO
# ..                                           ...
# 113                              WOODWAY PD WACO
# 114                                  BELLMEAD PD
# 115                                  BELLMEAD PD
# 116                                      WACO PD
# 117                                      WACO PD
#
#                                 agency_name_edit  agency_type_name  \
# 0    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO             Other
# 1    EAST CENTRAL IND SCHOOL DIST PD SAN ANTONIO             Other
# 2                      OLMOS PARK PD SAN ANTONIO              City
# 3                      OLMOS PARK PD SAN ANTONIO              City
# 4                        BEXAR CO SO SAN ANTONIO            County
# ..                                           ...               ...
# 113                              WOODWAY PD WACO              City
# 114                                  BELLMEAD PD              City
# 115                                  BELLMEAD PD              City
# 116                                      WACO PD              City
# 117                                      WACO PD              City
#
#      state_abbr                                         csv_header  \
# 0            TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 1            TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 2            TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 3            TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 4            TX  data_year,ori,state_abbr,agency_name_edit,agen...
# ..          ...                                                ...
# 113          TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 114          TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 115          TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 116          TX  data_year,ori,state_abbr,agency_name_edit,agen...
# 117          TX  data_year,ori,state_abbr,agency_name_edit,agen...
#
#     pe_ct_per_1000
# 0             0.00
# 1             0.00
# 2             5.34
# 3             5.65
# 4             0.00
# ..             ...
# 113           4.65
# 114           0.00
# 115           2.68
# 116           2.51
# 117           2.39
#
# [118 rows x 24 columns]

# %%
county_po=merge_df["county"].sum("total_pe_ct")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\pygmaps\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     458         try:
# --> 459             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     460         except KeyError:
#
# KeyError: 'total_pe_ct'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-2c8dbeed4ac4> in <module>
# ----> 1 county_po=merge_df["county"].sum("total_pe_ct")
#
# ~\.conda\envs\pygmaps\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11064             **kwargs,
#   11065         ):
# > 11066             return NDFrame.sum(
#   11067                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   11068             )
#
# ~\.conda\envs\pygmaps\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10784         **kwargs,
#   10785     ):
# > 10786         return self._min_count_stat_function(
#   10787             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10788         )
#
# ~\.conda\envs\pygmaps\lib\site-packages\pandas\core\generic.py in _min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10766                 name, axis=axis, level=level, skipna=skipna, min_count=min_count
#   10767             )
# > 10768         return self._reduce(
#   10769             func,
#   10770             name=name,
#
# ~\.conda\envs\pygmaps\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4164
#    4165         if axis is not None:
# -> 4166             self._get_axis_number(axis)
#    4167
#    4168         if isinstance(delegate, ExtensionArray):
#
# ~\.conda\envs\pygmaps\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     459             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     460         except KeyError:
# --> 461             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     462
#     463     @final
#
# ValueError: No axis named total_pe_ct for object type Series
